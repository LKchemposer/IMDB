# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

import re
import requests
from bs4 import BeautifulSoup as bs

# %%
csv = 'movies.csv'
movies = pd.read_csv(csv)
movies.head()
# Out:
#                                             Title  IMDBRating  \
# 0                                       It (2017)         7.4
# 1                     The Greatest Showman (2017)         7.7
# 2                           Thor: Ragnarok (2017)         7.9
# 3  Star Wars: Episode VIII - The Last Jedi (2017)         7.3
# 4                             Disobedience (2017)         6.8
#
#    IMDBRatingCount       ReleaseDate  RunTime UserCount CriticCount  \
# 0           286942  8 September 2017    135.0      1328         549
# 1           138013  20 December 2017    105.0      1160         302
# 2           357134   3 November 2017    130.0      1129         478
# 3           397407  15 December 2017    152.0      5360         639
# 4             5336     27 April 2018    114.0        50          88
#
#    Metascore Popularity PopularityTrend  \
# 0       69.0         15             +36
# 1       48.0         31              +1
# 2       74.0         33              -4
# 3       85.0         42             +18
# 4       74.0         54            +177
#
#                          ...                              Opening   GrossUSA  \
# 0                        ...                          123403419.0  327481748
# 1                        ...                            8805843.0  174307966
# 2                        ...                          122744989.0  315058289
# 3                        ...                          220009584.0  620181382
# 4                        ...                             237393.0    3478877
#
#     GrossIntl Country                                       PlotKeywords  \
# 0   700381748     USA  ['killer clown', 'clown', 'small town', 'ballo...
# 1   434236813     USA  ['social outcast', 'social prejudice', 'circus...
# 2   853977126     USA  ['marvel comics', 'marvel cinematic universe',...
# 3  1332704286     USA  ['wisecrack humor', 'sabotage', 'betrayal', 'd...
# 4     5290287      UK  ['lesbian relationship', "spitting in someone'...
#
#                                               Awards  \
# 0                       ['5 wins & 38 nominations.']
# 1  ['Nominated for 1 Oscar.', 'Another 8 wins & 2...
# 2                       ['5 wins & 36 nominations.']
# 3  ['Nominated for 4 Oscars.', 'Another 16 wins &...
# 4                                 ['2 nominations.']
#
#                                               Genres   MPAA  \
# 0                    ['Drama', 'Horror', 'Thriller']      R
# 1                  ['Biography', 'Drama', 'Musical']     PG
# 2  ['Action', 'Adventure', 'Comedy', 'Fantasy', '...  PG-13
# 3       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']  PG-13
# 4                               ['Drama', 'Romance']      R
#
#                                               ProdCo  \
# 0  ['New Line Cinema', 'RatPac-Dune Entertainment...
# 1  ['Chernin Entertainment', 'TSG Entertainment',...
# 2  ['Walt Disney Pictures', 'Marvel Studios', 'Sc...
# 3  ['Walt Disney Pictures', 'Lucasfilm', 'Ram Ber...
# 4     ['Braven Films', 'Element Pictures', 'Film 4']
#
#                                                Stars
# 0  ['Bill Skarsgård', 'Jaeden Lieberher', 'Finn W...
# 1  ['Hugh Jackman', 'Michelle Williams', 'Zac Efr...
# 2  ['Chris Hemsworth', 'Tom Hiddleston', 'Cate Bl...
# 3     ['Daisy Ridley', 'John Boyega', 'Mark Hamill']
# 4  ['Rachel Weisz', 'Rachel McAdams', 'Alessandro...
#
# [5 rows x 21 columns]

# %%
movies['Genres'] = movies['Genres'].str.strip('[]').str.replace('\'', '')
movies['ProdCo'] = movies['ProdCo'].str.strip('[]').str.replace('\'', '').str.replace('\"', '').str.replace('The', '')
movies['Stars'] = movies['Stars'].str.strip('[]').str.replace('\'', '').str.replace('\"', '')
movies['PlotKeywords'] = movies['PlotKeywords'].str.strip('[]').str.replace('\'', '')
movies['Awards'] = movies['Awards'].str.strip('[]').str.replace('\'', '').str.replace('.', '').str.lower().str.replace('for ', '').str.replace('wins', 'win'). str.replace('nominations', 'nomination')

# %%
movies[movies['Title'].duplicated()]
# Out:
#                     Title  IMDBRating  IMDBRatingCount  \
# 4631       Soldier (1998)         6.0            47420
# 5032       Soldier (1998)         6.2             2088
# 5033       Soldier (1998)         6.2             2088
# 6449   The Warrior (2001)         6.8             2275
# 6566   The Warrior (2001)         7.2            10318
# 6567   The Warrior (2001)         7.2            10318
# 8179         Chaos (2005)         6.5            47355
# 8298         Chaos (2005)         3.2             1865
# 8299         Chaos (2005)         3.2             1865
# 12820         Eden (2014)         4.7             2417
# 12855         Eden (2014)         6.4             3514
# 12856         Eden (2014)         6.4             3514
#
#                          ReleaseDate  RunTime UserCount CriticCount  \
# 4631                 23 October 1998     99.0       378          69
# 5032                 12 October 1998    156.0         6           1
# 5033                 12 October 1998    156.0         6           1
# 6449                    15 July 2005      NaN        43          32
# 6566         7 September 2001 (South    158.0        97          38
# 6567         7 September 2001 (South    158.0        97          38
# 8179   15 December 2005 (United Arab    106.0       103          49
# 8298                  10 August 2005     74.0        64          26
# 8299                  10 August 2005     74.0        64          26
# 12820              18 September 2015     90.0        13           8
# 12855                   19 June 2015    131.0        18         127
# 12856                   19 June 2015    131.0        18         127
#
#        Metascore Popularity PopularityTrend  \
# 4631         NaN      3,672            +943
# 5032         NaN        NaN             NaN
# 5033         NaN        NaN             NaN
# 6449        65.0        NaN             NaN
# 6566         NaN        NaN             NaN
# 6567         NaN        NaN             NaN
# 8179         NaN      4,544            -345
# 8298         1.0        NaN             NaN
# 8299         1.0        NaN             NaN
# 12820        NaN        NaN             NaN
# 12855       81.0        NaN             NaN
# 12856       81.0        NaN             NaN
#
#                              ...                            Opening  GrossUSA  \
# 4631                         ...                          6447237.0  14567883
# 5032                         ...                                NaN       NaN
# 5033                         ...                                NaN       NaN
# 6449                         ...                            14130.0     48160
# 6566                         ...                                NaN       NaN
# 6567                         ...                                NaN       NaN
# 8179                         ...                                NaN       NaN
# 8298                         ...                                NaN       NaN
# 8299                         ...                                NaN       NaN
# 12820                        ...                                NaN       NaN
# 12855                        ...                                NaN       NaN
# 12856                        ...                                NaN       NaN
#
#       GrossIntl      Country  \
# 4631        NaN        India
# 5032        NaN           UK
# 5033        NaN        India
# 6449        NaN  South Korea
# 6566        NaN           UK
# 6567        NaN  South Korea
# 8179    7000000          USA
# 8298        NaN       Canada
# 8299        NaN          USA
# 12820   1100000       France
# 12855       NaN        Spain
# 12856       NaN       France
#
#                                             PlotKeywords  \
# 4631   time bomb, soldier, planet, crash survivor, su...
# 5032           traitor, australia, army, vulture, murder
# 5033           traitor, australia, army, vulture, murder
# 6449              warrior, amulet, thief, village, sword
# 6566              battle, china, princess, desert, korea
# 6567              battle, china, princess, desert, korea
# 8179   chaos theory, power outage, investigation, exp...
# 8298   anal rape, breast removal, sexual violence, se...
# 8299   anal rape, breast removal, sexual violence, se...
# 12820  island, soccer team, plane crash, stranded, fl...
# 12855  drugs, dj, reference to daft punk, two parts, ...
# 12856  drugs, dj, reference to daft punk, two parts, ...
#
#                                                   Awards  \
# 4631                                        1 nomination
# 5032                                               5 win
# 5033                                               5 win
# 6449   nominated 1 bafta film award, another 8 win & ...
# 6566                                2 win & 2 nomination
# 6567                                2 win & 2 nomination
# 8179                                                 NaN
# 8298                                                 NaN
# 8299                                                 NaN
# 12820                                                NaN
# 12855                                       4 nomination
# 12856                                       4 nomination
#
#                                                   Genres       MPAA  \
# 4631                               Action, Drama, Sci-Fi          R
# 5032   Action, Drama, Musical, Mystery, Romance, Thri...        NaN
# 5033   Action, Drama, Musical, Mystery, Romance, Thri...        NaN
# 6449                                    Adventure, Drama          R
# 6566                         Action, Drama, History, War          R
# 6567                         Action, Drama, History, War          R
# 8179                      Action, Crime, Drama, Thriller          R
# 8298                                    Horror, Thriller  NOT RATED
# 8299                                    Horror, Thriller  NOT RATED
# 12820                                    Drama, Thriller          R
# 12855                            Biography, Drama, Music          R
# 12856                            Biography, Drama, Music          R
#
#                                                   ProdCo  \
# 4631   Warner Bros., Morgan Creek Entertainment Group...
# 5032                                                 NaN
# 5033                                                 NaN
# 6449   FilmFour, Senator Film Produktion, British Scr...
# 6566   Beijing Film Studio, CJ Entertainment, China Film
# 6567   Beijing Film Studio, CJ Entertainment, China Film
# 8179   Mobius International, Chaotic Productions, Cha...
# 8298                                                 NaN
# 8299                                                 NaN
# 12820       Gobsmack, H&H Creative Ventures, Ombra Films
# 12855   CG Cinéma, France 2 Cinéma, Blue Film Production
# 12856   CG Cinéma, France 2 Cinéma, Blue Film Production
#
#                                                    Stars
# 4631         Kurt Russell, Jason Scott Lee, Jason Isaacs
# 5032             Rakhee Gulzar, Bobby Deol, Preity Zinta
# 5033             Rakhee Gulzar, Bobby Deol, Preity Zinta
# 6449            Irrfan Khan, Puru Chibber, Aino Annuddin
# 6566               Woo-sung Jung, Sung-Ki Ahn, Jin-mo Ju
# 6567               Woo-sung Jung, Sung-Ki Ahn, Jin-mo Ju
# 8179        Jason Statham, Ryan Phillippe, Wesley Snipes
# 8298         Kevin Gage, Sage Stallone, Kelly K.C. Quann
# 8299         Kevin Gage, Sage Stallone, Kelly K.C. Quann
# 12820               James Remar, Diego Boneta, Rob Mayes
# 12855  Félix de Givry, Pauline Etienne, Vincent Macaigne
# 12856  Félix de Givry, Pauline Etienne, Vincent Macaigne
#
# [12 rows x 21 columns]

# %%
movies.drop([1318, 5032, 6566, 8298, 12855], inplace=True)

# %%
def clean_date(rows):
    i = rows['ReleaseDate']
    if pd.isna(i):
        return None
    elif '(' in i:
        return i.replace(i[i.rfind('('):], '').strip()
    else: return i

movies['ReleaseDate'] = movies.apply(clean_date, axis=1)
movies['ReleaseDate'] = pd.to_datetime(movies['ReleaseDate'], infer_datetime_format=True)

# %%
movies['UserCount'] = movies['UserCount'].str.extract('(\d+)').astype(float)
movies['CriticCount'] = movies['CriticCount'].str.extract('(\d+)').astype(float)
movies['Popularity'] = movies['Popularity'].str.replace(',', '').astype(float)
movies['PopularityTrend'] = movies['PopularityTrend'].str.replace(',', '').astype(float)

# %%
exchange = {'AED': 3.673226,'ARS': 27.19379, 'AUD': 1.352518, 'BRL': 3.876623, 'CAD': 1.317735,
            'CHF': 1.004057, 'CLP': 649.9436, 'CNY': 6.69011, 'CZK': 22.24431, 'DEM': 0.5981,
            'DKK': 6.366525, 'EUR': 0.858433, 'FRF': 0.858433, 'GBP': 0.758702, 'HKD': 7.848498,
            'HUF': 277.8622, 'IEP': 1.48384, 'ILS': 3.644134, 'ITL': 1656.86, 'INR': 68.5068,
            'ISK': 107.4348, 'JPY': 112.4974, 'KRW': 1127.11, 'KWD': 0.302817, 'MXN': 18.93298,
            'NOK': 8.136765, 'NZD': 1.481336, 'PEN': 3.276077, 'PHP': 53.52889, 'PKR': 121.6936,
            'PLN': 3.706481, 'RON': 4.01131, 'RUR': 62.27931, 'SAR': 3.750484, 'SEK': 8.902313,
            'SGD': 1.365964, 'THB': 33.30876, 'TWD': 30.60353, 'UAH': 26.23139, 'USD': 1.0,
            'XDR': 0.713272, 'ZAR': 13.30807, 'FIM': 0.19675, 'BEF': 0.028999, 'ESP': 0.007031,
            'TRL': 2.0765E-7, 'BND': 0.7398, 'NLG': 0.5283, 'DOP': 0.020178, 'JMD': 0.007663,
            'NPR': 0.0091, 'ATS': 0.8501, 'VND': 0.4349E-4}

# %%
movies['BudgetCurr'] = movies['Budget'].str.extract('(\D+)').replace('€', 'EUR').replace('£', 'GBP')[0].str.strip()
movies['Budget'] = movies['Budget'].str.extract('(\d+)').astype(float)

# %%
def adj_budget(rows):
    i = rows['Budget']
    j = rows['BudgetCurr']
    if pd.isna(i):
        return None
    if pd.isna(j):
        return i
    else: return i / exchange[j]

movies['Budget'] = movies.apply(adj_budget, axis=1)

# %%
movies['GrossUSA'] = movies['GrossUSA'].astype(float)

# %%
movies['GrossIntlCurr'] = movies['GrossIntl'].str.extract('(\D+)').replace('€', 'EUR').replace('£', 'GBP')[0].str.strip()
movies['GrossIntl'] = movies['GrossIntl'].str.extract('(\d+)').astype(float)

# %%
def adj_grossintl(rows):
    i = rows['GrossIntl']
    j = rows['GrossIntlCurr']
    if pd.isna(i):
        return None
    if pd.isna(j):
        return i
    else: return i / exchange[j]

movies['GrossIntl'] = movies.apply(adj_grossintl, axis=1)

# %%
movies.drop('BudgetCurr', axis=1, inplace=True)
movies.drop('GrossIntlCurr', axis=1, inplace=True)

# %%
def get_noms(rows):
    i = rows['Awards']
    if pd.isna(i):
        return None
    i = i.split()
    noms = 0
    try:
        i.index('nominated')
        noms += int(i[i.index('nominated') + 1])
    except ValueError:
        noms += 0
    try:
        i.index('nomination')
        noms += int(i[i.index('nomination') - 1])
    except ValueError:
        noms += 0
    return noms

def get_wins(rows):
    i = rows['Awards']
    if pd.isna(i):
        return None
    i = i.split()
    wins = 0
    try:
        i.index('won')
        wins += int(i[i.index('won') + 1])
    except ValueError:
        wins += 0
    try:
        i.index('win')
        wins += int(i[i.index('win') - 1])
    except ValueError:
        wins += 0
    return wins

# %%
movies['Noms'] = movies.apply(get_noms, axis=1)
movies['Wins'] = movies.apply(get_wins, axis=1)
movies['Awards'] = movies['Noms'] + movies['Wins']

# %%
genres = movies['Genres'].str.split(',').apply(pd.Series).stack().str.strip().reset_index()
idmb = movies['IMDBRating'].reset_index()
genres_eda = pd.merge(idmb, genres, left_on='index', right_on='level_0')
genres_eda.drop('level_0', axis=1, inplace=True)
genres_eda.drop('level_1', axis=1, inplace=True)
genres_eda.rename(columns={'index': 'ID', 0: 'Genres'}, inplace=True)

# %%
genres_eda.groupby('Genres')['IMDBRating'].size()
# Out:
# Genres
# Action       2852
# Adult           3
# Adventure    1594
# Animation     499
# Biography     654
# Comedy       4992
# Crime        2437
# Drama        8325
# Family       1022
# Fantasy      1265
# History       440
# Horror       1817
# Music         396
# Musical       314
# Mystery      1336
# Romance      3426
# Sci-Fi       1223
# Sport         368
# Thriller     4068
# War           451
# Western       167
# Name: IMDBRating, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 5))
p = sns.boxplot(x='Genres', y='IMDBRating', data=genres_eda);
plt.xticks(rotation=90);

# %%
movies['MPAA'] = movies['MPAA'].str.replace('UNRATED', 'NOT RATED')

# %%
movies.loc[movies['MPAA'].isin(['AO', 'M', 'TV-Y7', 'TV-Y', 'X', 'TV-G']), ['MPAA']] = 'OTHER'

# %%
fig, ax = plt.subplots(figsize=(7, 5))
p = sns.boxplot(x='MPAA', y='IMDBRating', data=movies);
plt.xticks(rotation=90);

# %%
prodco = movies['ProdCo'].str.split(',').apply(pd.Series).stack().str.strip().reset_index()
prodco.drop(list(prodco[prodco[0] == ''].index), inplace=True)
prodco_eda = pd.merge(idmb, prodco, left_on='index', right_on='level_0')
prodco_eda.drop('level_0', axis=1, inplace=True)
prodco_eda.drop('level_1', axis=1, inplace=True)
prodco_count = prodco_eda[0].value_counts().reset_index()
prodco_other = prodco_count[prodco_count[0] < 10]['index']
prodco.loc[prodco[0].isin(prodco_other), 0] = 'Other'

# %%
prodco_transf = prodco.groupby('level_0')[0].apply(lambda i: ', '.join(i)).reset_index().set_index('level_0')
movies = movies.join(prodco_transf)
movies['ProdCo'] = movies[0]
movies.drop(0, axis=1, inplace=True)

# %%
movies.to_csv('movies_clean.csv', index=False)
